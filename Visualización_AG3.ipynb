# %% [markdown]
# <a href="https://colab.research.google.com/github/Kantkar/AG1/blob/master/Visualizaci%C3%B3n_AG3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import io
import requests
import seaborn as sns
import timeit
import matplotlib.pyplot as plt

# %%
#Cargamos el fichero donde esta el dataset
url="https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
s=requests.get(url).content
titanic=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null object
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null object
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.3+ KB

# %%
#Renombramos las columnas class y fare
titanic.rename(columns={'class': 'clase'},inplace=True)
titanic.rename(columns={'fare': 'tarifa'},inplace=True)
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# tarifa         891 non-null float64
# embarked       889 non-null object
# clase          891 non-null object
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null object
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.3+ KB

# %%
#Muestra los valores distintos para class=clase
titanic.clase.unique()
# Out:
# array(['Third', 'First', 'Second'], dtype=object)

# %%
#Primeras 5 filas
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch   tarifa embarked  clase  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#Definimos una nueva funcion para clasificar como 1 2 y 3 a una nueva columna num
def class_num_func(row):
    Clase={'Third':3,'First':1,'Second':2}
    return Clase[row.clase]
titanic['class_num'] = titanic.apply(class_num_func, axis='columns')
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch   tarifa embarked  clase  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  class_num
# 0    man        True  NaN  Southampton    no  False          3
# 1  woman       False    C    Cherbourg   yes  False          1
# 2  woman       False  NaN  Southampton   yes   True          3
# 3  woman       False    C  Southampton   yes  False          1
# 4    man        True  NaN  Southampton    no   True          3

# %%
#Añadimos nuevas columnas: is_old, is_baby
def is_old_func(row):
 return row['age'] > 60
titanic['is_old'] = titanic.apply(is_old_func, axis='columns')

# %%
#Otra forma de definir una nueva columna
titanic.eval ( ' is_baby = age< 15 ' , inplace = True)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch   tarifa embarked  clase  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  class_num  is_old  \
# 0    man        True  NaN  Southampton    no  False          3   False
# 1  woman       False    C    Cherbourg   yes  False          1   False
# 2  woman       False  NaN  Southampton   yes   True          3   False
# 3  woman       False    C  Southampton   yes  False          1   False
# 4    man        True  NaN  Southampton    no   True          3   False
#
#    is_baby
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %%
#Define una variable numérica: class_num
def class_num_func(row):
 Clase={'Third':3,'First':1,'Second':2}
 return Clase[row.clase]
titanic['class_num'] = titanic.apply(class_num_func, axis='columns')

# %%
#Convierte los nuevos valores a numéricos
titanic = titanic.convert_objects(convert_numeric=True)
titanic.head(5)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
#    survived  pclass     sex   age  sibsp  parch   tarifa embarked  clase  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  class_num  is_old  \
# 0    man        True  NaN  Southampton    no  False          3   False
# 1  woman       False    C    Cherbourg   yes  False          1   False
# 2  woman       False  NaN  Southampton   yes   True          3   False
# 3  woman       False    C  Southampton   yes  False          1   False
# 4    man        True  NaN  Southampton    no   True          3   False
#
#    is_baby
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %%
#Define una variable numérica: class_num
def class_num_func(row):
 Clase={'Third':3,'First':1,'Second':2}
 return Clase[row.clase]
titanic['class_num'] = titanic.apply(class_num_func, axis='columns')
#Convierte los nuevos valores a numericos
titanic["class_num"] = titanic.class_num.astype('float64')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch   tarifa embarked  clase  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  class_num  is_old  \
# 0    man        True  NaN  Southampton    no  False        3.0   False
# 1  woman       False    C    Cherbourg   yes  False        1.0   False
# 2  woman       False  NaN  Southampton   yes   True        3.0   False
# 3  woman       False    C  Southampton   yes  False        1.0   False
# 4    man        True  NaN  Southampton    no   True        3.0   False
#
#    is_baby
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %%
#Consulta con condiciones
titanic[
 (titanic.sex == 'female')
 & (titanic['clase'].isin(['First',
'Third']))
 & (titanic.age > 45 )
 & (titanic.survived == 0)
]
# Out:
#      survived  pclass     sex   age  sibsp  parch   tarifa embarked  clase  \
# 132         0       3  female  47.0      1      0  14.5000        S  Third
# 177         0       1  female  50.0      0      0  28.7125        C  First
# 736         0       3  female  48.0      1      3  34.3750        S  Third
#
#        who  adult_male deck  embark_town alive  alone  class_num  is_old  \
# 132  woman       False  NaN  Southampton    no  False        3.0   False
# 177  woman       False    C    Cherbourg    no   True        1.0   False
# 736  woman       False  NaN  Southampton    no  False        3.0   False
#
#      is_baby
# 132    False
# 177    False
# 736    False

# %%
#Distribución de las clases
sns.countplot(x="pclass", data=titanic)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
#Distribución de la edad(ege)
sns.distplot (titanic.age.dropna( ))
sns.plt.show ( )
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
#Distribución cruzada de Edad y Tarifa
sns.jointplot(x='tarifa',y='age',data=titanic)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
#Cambiamos el font
sns.set(font_scale=0.5)
g = sns.FacetGrid(titanic, row='survived',
col='clase')
g.map(sns.distplot, "age")
sns.plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
#Diagrama de dispersion con Distribucion de cadavariable: tarifa(precio)/age(edad)
sns.jointplot(data=titanic, x='age', y='tarifa',
kind='reg', color='b')
sns.plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
# Mapa de calor de correlaciones
tc = titanic.corr()
sns.heatmap(tc,cmap='coolwarm')
plt.title('titanic.corr()')
# Out:
# Text(0.5, 1.0, 'titanic.corr()')

# %%
#Define un subconjuto de datos con las variables numéricas
titanic_num = titanic[['survived','pclass','sibsp','parch','tarifa']]
#Hace una matriz de diagramas de dispersión de parejas de variables.
sns.pairplot(titanic_num, hue="survived")
sns.plt.show()

# %%
#Generamos diagramas de dispersión de parejas de variables cuantitativas utilizando el dataset iris.
sns.set(style="ticks")
df = sns.load_dataset("iris")
sns.pairplot(df, hue="species")
